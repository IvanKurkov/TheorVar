# %% [markdown]
# ### Задача 1
# Используя данные о хоккеистах (скачать можно здесь), проверьте, является ли среди хоккеистов из Финляндии, Норвегии и Дании значимым отличие: а) роста, б) BMI.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %%
df = pd.read_csv("hockey_players.csv")
df
# Out:
#       year country  no                 name position side  height  weight  \
# 0     2001     RUS  10     tverdovsky oleg         D    L     185    84.0
# 1     2001     RUS   2   vichnevsky vitali         D    L     188    86.0
# 2     2001     RUS  26  petrochinin evgeni         D    L     182    95.0
# 3     2001     RUS  28     zhdan alexander         D    R     178    85.0
# 4     2001     RUS  32     orekhovsky oleg         D    R     175    88.0
# ...    ...     ...  ..                  ...      ...  ...     ...     ...
# 3289  2016     USA   7         compher j.t.        F    R     180    87.0
# 3290  2016     USA  72        vatrano frank        F    L     178    98.0
# 3291  2016     USA   1        kinkaid keith        G    L     191    88.0
# 3292  2016     USA  30          condon mike        G    L     188    89.0
# 3293  2016     USA  31       demko thatcher        G    L     193    95.0
#
#            birth                     club        age  cohort        bmi
# 0     1976-05-18    anaheim mighty ducks   24.952772    1976  24.543462
# 1     1980-03-18    anaheim mighty ducks   21.119781    1980  24.332277
# 2     1976-02-07  severstal cherepovetal   25.229295    1976  28.680111
# 3     1971-08-28           ak bars kazan   29.675565    1971  26.827421
# 4     1977-11-03           dynamo moscow   23.490760    1977  28.734694
# ...          ...                      ...        ...     ...        ...
# 3289  1995-04-08   university of michigan  21.065024    1995  26.851852
# 3290  1994-03-14            boston bruins  22.132786    1994  30.930438
# 3291  1989-07-04        new jersey devils  26.825462    1989  24.122146
# 3292  1990-04-27       montreal canadiens  26.012320    1990  25.181077
# 3293  1995-12-08           boston college  20.396988    1995  25.504040
#
# [3294 rows x 13 columns]

# %%
y1 = df[df["country"] == "FIN"]["height"]
y2 = df[df["country"] == "NOR"]["height"]
y3 = df[df["country"] == "DEN"]["height"]

# %%
stats.f_oneway(y1, y2, y3)
# Out:
# F_onewayResult(statistic=3.593457507240696, pvalue=0.02833215521299233)

# %%
n1 = y1.shape[0]
n2 = y2.shape[0]
n3 = y3.shape[0]

# %%
y1_mean = y1.mean()
y2_mean = y2.mean()
y3_mean = y3.mean()

# %%
y = df[df["country"].isin(["FIN", "NOR", "DEN"])]["height"]

# %%
y_mean = y.mean()

# %%
SS_b = n1 * (y1_mean - y_mean) ** 2 + n2 * (y2_mean - y_mean) ** 2 + n3 * (y3_mean - y_mean) ** 2

SS_w = ((y1 - y1_mean) ** 2).sum() + ((y2 - y2_mean) ** 2).sum() + ((y3 - y3_mean) ** 2).sum()

# %%
k = 3
n = n1 + n2 + n3

k1 = k - 1
k2 = n - k

sigma2_b = SS_b / k1
sigma2_w = SS_w / k2

sigma2_b, sigma2_w
# Out:
# (93.14492174795387, 25.920696588250017)

# %%
F = sigma2_b / sigma2_w
F
# Out:
# 3.59345750724064

# %%
alpha = 0.05

t = stats.f.ppf(1 - alpha, k1, k2)
t
# Out:
# 3.016700272452327

# %% [markdown]
# Принимаем H1 - разница роста по странам значима.

# %%
y1 = df[df["country"] == "FIN"]["bmi"]
y2 = df[df["country"] == "NOR"]["bmi"]
y3 = df[df["country"] == "DEN"]["bmi"]

# %%
stats.f_oneway(y1, y2, y3)
# Out:
# F_onewayResult(statistic=8.682513420531995, pvalue=0.00020108587146857798)

# %% [markdown]
# Принимаем H1 - разница bmi по странам значима.

# %% [markdown]
# #### Ответ: в обоих случаях различие значимо

# %%
us = [df[df["country"] == i]["bmi"] for i in df["country"].unique()]

# %%
# Out:
# [0       24.543462
#  1       24.332277
#  2       28.680111
#  3       26.827421
#  4       28.734694
#            ...
#  3149    26.595745
#  3150    27.173102
#  3151    24.698650
#  3152    24.835646
#  3153    22.068809
#  Name: bmi, Length: 220, dtype: float64,
#  24      26.566840
#  25      26.566840
#  26      28.734694
#  27      25.464011
#  28      26.592798
#            ...
#  3060    25.661152
#  3061    28.233875
#  3062    26.264944
#  3063    25.925926
#  3064    23.235632
#  Name: bmi, Length: 137, dtype: float64,
#  47      25.737081
#  48      27.465303
#  49      27.471689
#  50      26.309431
#  51      27.170632
#            ...
#  3154    25.661152
#  3155    25.082863
#  3156    26.309017
#  3157    25.737081
#  3158    26.029878
#  Name: bmi, Length: 160, dtype: float64,
#  70      27.072053
#  71      27.411529
#  72      26.040953
#  73      26.583176
#  74      24.593211
#            ...
#  3169    25.761773
#  3170    26.794938
#  3171    24.835646
#  3172    26.880935
#  3173    22.714681
#  Name: bmi, Length: 265, dtype: float64,
#  97      24.810964
#  98      28.086269
#  99      25.766838
#  100     27.774423
#  101     26.583176
#            ...
#  3184    24.485652
#  3185    25.725517
#  3186    27.434842
#  3187    23.795526
#  3188    25.746944
#  Name: bmi, Length: 207, dtype: float64,
#  120     26.287807
#  121     26.196187
#  122     27.774271
#  123     25.420015
#  124     26.855469
#            ...
#  3194    26.575891
#  3195    24.419279
#  3196    24.976087
#  3197    27.777778
#  3198    26.584201
#  Name: bmi, Length: 201, dtype: float64,
#  144     25.617284
#  145     23.374726
#  146     28.905076
#  147     26.874496
#  148     24.414062
#            ...
#  3203    26.264944
#  3204    24.691358
#  3205    25.484765
#  3206    27.170771
#  3207    25.335002
#  Name: bmi, Length: 181, dtype: float64,
#  169     24.755464
#  170     24.489796
#  171     27.173119
#  172     25.592210
#  173     25.617284
#            ...
#  2975    28.405504
#  2976    25.737081
#  2977    28.409091
#  2978    25.680074
#  2979    24.835646
#  Name: bmi, Length: 102, dtype: float64,
#  192     25.469388
#  193     23.939481
#  194     23.148148
#  195     23.573915
#  196     25.640243
#            ...
#  1013    26.250725
#  1014    24.074074
#  1015    25.351541
#  1016    23.765432
#  1017    22.205990
#  Name: bmi, Length: 69, dtype: float64,
#  215     24.898144
#  216     25.218607
#  217     25.249337
#  218     24.653740
#  219     25.484765
#            ...
#  3103    26.264944
#  3238    26.881720
#  3239    25.401701
#  3240    25.308642
#  3241    23.299800
#  Name: bmi, Length: 138, dtype: float64,
#  237     26.840610
#  238     24.302487
#  239     25.381469
#  240     24.968010
#  241     27.770313
#            ...
#  3242    25.127831
#  3243    25.945484
#  3244    23.765432
#  3245    25.306932
#  3246    25.436467
#  Name: bmi, Length: 98, dtype: float64,
#  260     24.879179
#  261     27.423823
#  262     26.315789
#  263     26.863299
#  264     26.583176
#            ...
#  3251    27.102041
#  3252    24.419279
#  3253    23.030045
#  3254    26.315789
#  3255    23.671254
#  Name: bmi, Length: 164, dtype: float64,
#  283     27.700831
#  284     26.863299
#  285     25.732771
